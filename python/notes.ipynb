# %% [markdown]
# # Python - Revision Notes
#
# ## 1. Python Fundamentals
# - `print()`
# - Variables and basic data types
# - Functions
# - Parameters vs arguments
# - `return` vs `print`
# - Default arguments
# - Keyword arguments
# - `*args` and `**kwargs`
# - Local vs global scope
#
# ## 2. Core Data Structures
# ### Lists
# - Indexing and slicing
# - Nested lists
# - List comprehensions
#
# ### Tuples
# - Immutable sequence
# - Indexing/slicing
#
# ### Sets
# - Unique values
# - Membership testing
#
# ### Dictionaries
# - Key-value structure
# - Nested dictionaries
# - Dictionary comprehensions
# - Frequency maps
# - Average O(1) lookup/membership
#
# ### Useful built-ins / string operations
# - `enumerate()`
# - `split()`
# - `join()`
# - slicing
#
# ## 3. Python Object Model
# - Everything in Python is an object
# - Variables are names/references to objects
# - `id()` and `type()`
# - `==` vs `is`
# - Mutable vs immutable objects
# - Aliasing
# - Shallow copy vs deep copy
# - `copy.deepcopy()`
#
# ## 4. Hashing
# - What hashing means
# - Hash tables
# - Dictionary lookup: average O(1)
# - Set membership: average O(1)
# - Hash collisions
# - Hashable vs unhashable objects
# - Frequency-map pattern
#
# ## 5. OOP
# - Classes and objects
# - `__init__`
# - Instance attributes and methods
# - Static methods
# - Object/reference manipulation
# - Basic abstraction
#
# ## 6. Functions & Recursion
# - Function definitions
# - Arguments and return values
# - Recursion
# - Iterative vs recursive implementations
# - `None` handling
#
# ## 7. Iterators & Generators
# ### Iterable → Iterator
# ```python
# it = iter(data)
# next(it)
# ```
#
# - Iterators produce values one at a time
# - `StopIteration` signals exhaustion
#
# ### Generators
# ```python
# def numbers():
#     yield 1
#     yield 2
# ```
#
# - `yield` makes a function a generator
# - Execution pauses/resumes around `yield`
# - Lazy evaluation
# - Memory efficient for large/streaming data
#
# ### Generator expressions
# ```python
# squares = (x * x for x in range(1_000_000))
# ```
#
# ## 8. Decorators
# A decorator adds behavior to a function without changing its core implementation.
#
# ```python
# from functools import wraps
#
# def logger(func):
#     @wraps(func)
#     def wrapper(*args, **kwargs):
#         print("Function started")
#         result = func(*args, **kwargs)
#         print("Function finished")
#         return result
#     return wrapper
#
# @logger
# def add(a, b):
#     return a + b
# ```
#
# Important idea:
# ```python
# @logger
# def add(...):
#     ...
# ```
# is effectively:
# ```python
# add = logger(add)
# ```
#
# Common engineering uses:
# - Logging
# - Caching
# - Retry logic
# - FastAPI route decorators
#
# ## 9. Context Managers
# Basic concept:
# ```python
# with open("file.txt") as f:
#     data = f.read()
# ```
#
# Context managers manage setup/cleanup around a block.
#
# Key protocol:
# - `__enter__`
# - `__exit__`
#
# ## 10. Type Hints
# Modern examples:
# ```python
# name: str
# age: int
# scores: list[float]
# metadata: dict[str, float]
# value: str | None
# ```
#
# Function example:
# ```python
# def add(a: int, b: int) -> int:
#     return a + b
# ```
#
# Useful for readability, tooling, IDE support, and production Python.
#
# ## 11. Async Python — Conceptual Revision
# - `async def` defines a coroutine
# - `await` pauses the coroutine while waiting for an async operation
# - Useful for I/O-bound workloads
# - Deeper async/backend patterns will be covered later during AI Engineering
#
# ## 12. DSA-Related Python Practice
# Python has been used to implement:
# - Arrays and strings
# - Sliding window
# - Prefix sum
# - Stack patterns
# - Linked lists
# - Recursive linked-list reversal
# - Iterative linked-list reversal
# - Doubly linked lists
# - Circular linked lists
# - Cycle detection
# - Node insertion/deletion
#
# ## 13. Phase 0 Python Engineering Gaps to Revisit Later
# These were intentionally kept compact so we can move quickly:
# - Modules and packages
# - Advanced closures/decorators
# - Exception architecture
# - Logging
# - Async Python in depth
# - Project architecture
#
# These will be learned naturally during AI/backend engineering rather than blocking progress.
#
# ---
#
# # Quick Mental Model
#
# ```text
# Python for AI
# │
# ├── Core syntax & data structures
# ├── Object model & mutability
# ├── Hashing
# ├── OOP
# ├── Functions & recursion
# ├── Iterators & generators
# ├── Decorators
# ├── Context managers
# ├── Type hints
# └── Async basics
# ```
#
# **Status: Python Phase 0 foundation — DONE**
